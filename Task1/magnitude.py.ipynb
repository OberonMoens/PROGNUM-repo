# %%
# Sirius data
# apparentMagnitude = -1.46
# absoluteMagnitude = 1.45

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = eval(input("input the apparent magnitude: "))
M = eval(input("input the absolute magnitude: "))

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164

print(f"The resulting distance is {d} lightyears!")
# Out:
# input the apparent magnitude: -1.46
# input the absolute magnitude: 1.45
# The resulting distance is 8.53957042692737 lightyears!
