# %% [markdown]
# Answers for Week 1
#
# * Name: Oberon Moens
# * Username: opmoens
# * Student s-number: s4508602
# * Group (AS1, etc.): AS1

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# $$F=G\frac{m_1m_2}{r^2}$$

# %%
import math
from scipy.constants import G

M = 7.342*10**22
A = 5.9722*10**24
r = 385000600

F = (G*M*A)/(r**2)

print(F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# Question 1.15:
# 1. /Users/users/opmoens/Downloads
# 2. Current directory and parent directory

# %% [markdown]
# Question 1.16:
#
# 1. cd ~/Desktop

# %% [markdown]
# Question 1.19:
#
# 1. This command will list all documents that before the point have a number in 0-9 in their name and after the point has either .0 or .c
# 2. The square brackets indicate the range of numbers of [0-9] and for [co] it means that after the point i has to either have c or an o
# 3. The difference is that in this one it only lists files that have the extension .co not .c or .o but ONLY .co
