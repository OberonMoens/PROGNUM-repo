# %%
#question 2.21

#Assign first two terms
f1 = 1
f2 = 2

for i in range(99):
    f1 += f2 #add the terms in f1
    f3 = f1 #swap the integers
    f1 = f2
    f2 = f3
    
print(f1)
# Out:
# 573147844013817084101
