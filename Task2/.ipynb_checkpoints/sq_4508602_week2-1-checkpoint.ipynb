# %% [markdown]
# Answers for Week 2
#
# * Name: Oberon Moens
# * Username: opmoens
# * Student s-number: s4508602
# * Group (AS1, etc.): AS1

# %% [markdown]
# Question 2.5: $$\newline$$
#
# $$\displaystyle\sum_{k=0}^{\infty} \frac{1}{4k^2-1} =\frac{1}{2}$$
# $$\int_0^\pi \mathrm{e}^{ix} \mathrm{d}x = 2i$$

# %%
#Question 2.12:
from math import atan2, degrees

#Input for x and y coordinates
x = float(input("input x-coordinate:"))
y = float(input("input y-coordinate:"))

phi = atan2(x,y)

print(f"θ = {phi} radians")

#if statements to print what quadrant for x and y
if x > 0 and y > 0:
    print("top-right quadrant")
elif x > 0 and y < 0:
    print("bottom-right quadrant")
elif x < 0 and y > 0:
    print("top-left quadrant")
elif x < 0 and y < 0:
    print("bottom-left quadrant")
# Out:
# input x-coordinate:3
# input y-coordinate:-1
# θ = 1.892546881191539 radians
# bottom-right quadrant

# %% [markdown]
# Question 2.12b:
# The difference between math.atan and math.atan2 is that math.atan takes the ratio between the coordinates x and y and math.atan2 takes both x and y coordinates separately and computes the full range of $-\pi$ and $\pi$

# %%
#question 2.14
#Create list
x = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]

#add and remove from list
x.append(0.51)
x.remove(2.12)

print(x)

#printing values
print(x[6])
print(f"index for value 1.46 is at {x.index(1.46)}")

print(x[2:-3:2])
print(round(sum(x[2:-3:2]),2))
# Out:
# [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# 1.97
# index for value 1.46 is at 1
# [1.41, 0.98, 1.97]
# 4.36

# %%
#question 2.15

night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

newList = night1 and night2
print(f"The intersection list is: {newList}")
if 5 in newList:
    print("Yes, 5 is in the intersection list")
else:
    print("No, 5 is not in the intersection list")
    
if 5 in night1:
    print("Yes, 5 is in the night1 list")
else:
    print("No, 5 is not in the night1 list")
# Out:
# The intersection list is: [0, 0, 2, 4, 2, 4, 3, 2, 1, 1, 1, 2, 0]
# No, 5 is not in the intersection list
# Yes, 5 is in the night1 list
